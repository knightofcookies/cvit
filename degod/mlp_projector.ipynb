# %% [markdown]
# # Install packages

# %%
# !pip install transformers==4.56.2
# !pip install --no-deps trl==0.22.2
# !pip install jiwer
# !pip install einops addict easydict
# !pip install verovio
# !pip install faker
# !pip install peft
# Out:
# Collecting transformers==4.56.2
#   Downloading transformers-4.56.2-py3-none-any.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers==4.56.2) (3.20.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.56.2) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.56.2) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.56.2) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.56.2) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.56.2) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers==4.56.2) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.56.2) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers==4.56.2) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers==4.56.2) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers==4.56.2) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers==4.56.2) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers==4.56.2) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.56.2) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.56.2) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.56.2) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.56.2) (2026.1.4)
# Downloading transformers-4.56.2-py3-none-any.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 136.6 MB/s eta 0:00:00
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.57.3
#     Uninstalling transformers-4.57.3:
#       Successfully uninstalled transformers-4.57.3
# Successfully installed transformers-4.56.2
# Collecting trl==0.22.2
#   Downloading trl-0.22.2-py3-none-any.whl.metadata (11 kB)
# Downloading trl-0.22.2-py3-none-any.whl (544 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 544.8/544.8 kB 13.5 MB/s eta 0:00:00
# Installing collected packages: trl
# Successfully installed trl-0.22.2
# Collecting jiwer
#   Downloading jiwer-4.0.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: click>=8.1.8 in /usr/local/lib/python3.12/dist-packages (from jiwer) (8.3.1)
# Collecting rapidfuzz>=3.9.7 (from jiwer)
#   Downloading rapidfuzz-3.14.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (12 kB)
# Downloading jiwer-4.0.0-py3-none-any.whl (23 kB)
# Downloading rapidfuzz-3.14.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 58.0 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, jiwer
# Successfully installed jiwer-4.0.0 rapidfuzz-3.14.3
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (0.8.1)
# Collecting addict
#   Downloading addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.12/dist-packages (1.13)
# Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Installing collected packages: addict
# Successfully installed addict-2.4.0
# Collecting verovio
#   Downloading verovio-5.7.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.2 kB)
# Downloading verovio-5.7.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 92.1 MB/s eta 0:00:00
# Installing collected packages: verovio
# Successfully installed verovio-5.7.0
# Collecting faker
#   Downloading faker-40.1.2-py3-none-any.whl.metadata (16 kB)
# Downloading faker-40.1.2-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 40.8 MB/s eta 0:00:00
# Installing collected packages: faker
# Successfully installed faker-40.1.2
# Requirement already satisfied: peft in /usr/local/lib/python3.12/dist-packages (0.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from peft) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from peft) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from peft) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from peft) (6.0.3)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from peft) (2.9.0+cu126)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from peft) (4.56.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from peft) (4.67.1)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from peft) (1.12.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from peft) (0.7.0)
# Requirement already satisfied: huggingface_hub>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from peft) (0.36.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.25.0->peft) (3.20.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.25.0->peft) (2025.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.25.0->peft) (2.32.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.25.0->peft) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.25.0->peft) (1.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (3.5.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers->peft) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->peft) (0.22.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.13.0->peft) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.25.0->peft) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.25.0->peft) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.25.0->peft) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.25.0->peft) (2026.1.4)

# %% [markdown]
# ### HF Login for Kaggle

# %%
# from huggingface_hub import login
# from kaggle_secrets import UserSecretsClient
# user_secrets = UserSecretsClient()
# token = user_secrets.get_secret("HF_TOKEN")
# login(token=token)

# %% [markdown]
# ### Hotfix (Transformers >= 4.46 compatibility)

# %%
import transformers.models.llama.modeling_llama
if not hasattr(transformers.models.llama.modeling_llama, "LlamaFlashAttention2"):
    print(">>> Monkeypatching LlamaFlashAttention2 for DeepSeek-OCR compatibility...")
    transformers.models.llama.modeling_llama.LlamaFlashAttention2 = transformers.models.llama.modeling_llama.LlamaAttention
# Out:
# >>> Monkeypatching LlamaFlashAttention2 for DeepSeek-OCR compatibility...

# %% [markdown]
# # Imports

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset
from transformers import (
    AutoModel,
    AutoModelForCausalLM,
    AutoTokenizer,
    Trainer,
    TrainingArguments,
    PreTrainedModel
)
from transformers.modeling_outputs import CausalLMOutputWithPast
import torchvision.transforms as T
import warnings
import gc
from PIL import Image, ImageDraw, ImageFont
import os
import json
import random
from faker import Faker
from peft import get_peft_model, LoraConfig
import types

os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# %% [markdown]
# # Projector MLP

# %%
class DeepSeekOCRToGOTProjector(nn.Module):
    def __init__(self, encoder_dim, decoder_dim=1024):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(encoder_dim, decoder_dim * 2),
            nn.GELU(),
            nn.Linear(decoder_dim * 2, decoder_dim),
            nn.LayerNorm(decoder_dim)
        )

    def forward(self, x):
        return self.net(x)

# %% [markdown]
# # Fusion Model

# %%
class DeepSeekFeatureExtractor(nn.Module):
    """
    Wraps the internal DeepSeek-OCR modules to perform the full
    SAM + CLIP + Projection forward pass, treating the output as a 1D sequence.
    """
    def __init__(self, base_model):
        super().__init__()
        # Extract sub-modules from the base DeepSeek-OCR model
        self.sam_model = base_model.sam_model
        self.vision_model = base_model.vision_model
        self.projector = base_model.projector

    def forward(self, images):
        # 1. Run SAM Backbone
        sam_features = self.sam_model(images)

        # 2. Run Vision Backbone (CLIP) with SAM injection
        vision_features = self.vision_model(images, sam_features)

        # 3. Fuse Features
        # SAM: [B, C_sam, H, W] -> [B, H*W, C_sam]
        sam_flat = sam_features.flatten(2).permute(0, 2, 1)
        # CLIP: [B, 1+L, C_clip] -> [B, L, C_clip] (skipping CLS token)
        clip_flat = vision_features[:, 1:]

        fused_features = torch.cat((clip_flat, sam_flat), dim=-1)

        # 4. Run Internal Projector
        # Projects fused features to the cross-modal dimension [B, L, C]
        final_features = self.projector(fused_features)

        # We return the flattened 1D sequence without inserting image newline tokens
        return final_features

# %%
class DeepSeekGOTFusion(nn.Module):
    def __init__(self, deepseek_ocr_path, got_path, tokenizer, use_lora=True):
        super().__init__()

        self.tokenizer = tokenizer 

        warnings.filterwarnings("ignore")
        frozen_dtype = torch.bfloat16 if torch.cuda.is_bf16_supported() else torch.float16
        self.vision_dtype = frozen_dtype

        # --- 1. Load DeepSeek Encoder ---
        print(f">>> Loading DeepSeek-OCR Encoder...")
        deepseek_model = AutoModel.from_pretrained(
            deepseek_ocr_path,
            trust_remote_code=True,
            torch_dtype=frozen_dtype,
        )
        base_vision = deepseek_model.model if hasattr(deepseek_model, "model") else deepseek_model
        self.vision_tower = DeepSeekFeatureExtractor(base_vision)
        self.vision_dim = 1280

        for param in self.vision_tower.parameters():
            param.requires_grad = False

        # --- 2. Load GOT-OCR Decoder (Use ForCausalLM to enable internal loss/head) ---
        print(f">>> Loading GOT-OCR Decoder (AutoModelForCausalLM)...")
        self.decoder = AutoModelForCausalLM.from_pretrained(
            got_path,
            trust_remote_code=True,
            torch_dtype=frozen_dtype,
        )
        self.decoder_dim = self.decoder.config.hidden_size

        # --- 3. LoRA Injection ---
        self.decoder.requires_grad_(False)
        if use_lora:
            print(">>> Injecting LoRA Adapters...")
            lora_config = LoraConfig(
                r=16,
                lora_alpha=32,
                target_modules=["q_proj", "k_proj", "v_proj", "o_proj", "gate_proj", "up_proj", "down_proj"],
                lora_dropout=0.05,
                bias="none",
                task_type="CAUSAL_LM"
            )
            self.decoder = get_peft_model(self.decoder, lora_config)
            self.decoder.print_trainable_parameters()

        # --- 4. Projector ---
        self.projector = DeepSeekOCRToGOTProjector(self.vision_dim, self.decoder_dim)
        self.projector.apply(self._init_weights)

        self.img_start_id = tokenizer.convert_tokens_to_ids("<img>")
        self.img_end_id = tokenizer.convert_tokens_to_ids("</img>")

        self.vision_tower.requires_grad_(False)
        self.projector.requires_grad_(True)

    def _init_weights(self, m):
        if isinstance(m, nn.Linear):
            nn.init.trunc_normal_(m.weight, std=0.01)
            if m.bias is not None:
                nn.init.zeros_(m.bias)
        elif isinstance(m, nn.LayerNorm):
            nn.init.ones_(m.weight)
            nn.init.zeros_(m.bias)

    def gradient_checkpointing_enable(self, gradient_checkpointing_kwargs=None):
        if hasattr(self.decoder, "gradient_checkpointing_enable"):
            self.decoder.gradient_checkpointing_enable(gradient_checkpointing_kwargs=gradient_checkpointing_kwargs)

    def save_pretrained(self, save_directory):
        if not os.path.exists(save_directory): os.makedirs(save_directory)
        torch.save(self.projector.state_dict(), os.path.join(save_directory, "pytorch_model.bin"))
        if hasattr(self.decoder, "save_pretrained"):
             self.decoder.save_pretrained(save_directory)
        with open(os.path.join(save_directory, "config.json"), "w") as f:
            json.dump({
                "vision_dim": self.vision_dim,
                "decoder_dim": self.decoder_dim,
                "architecture": "DeepSeekOCRToGOTProjector"
            }, f, indent=4)

    def forward(self, pixel_values, input_ids, attention_mask=None, labels=None, **kwargs):
        # 1. Vision Encode
        with torch.no_grad():
            vision_out = self.vision_tower(pixel_values.to(self.vision_dtype))
            if isinstance(vision_out, (tuple, list)):
                features = vision_out[0]
            elif hasattr(vision_out, "last_hidden_state"):
                features = vision_out.last_hidden_state
            else:
                features = vision_out
            features = features.detach()

        # 2. Project
        vision_embeds = self.projector(features.to(torch.float32)).to(self.vision_dtype)
        B, N, _ = vision_embeds.shape
        device = vision_embeds.device

        # 3. Text Embeds
        base_decoder = self.decoder.get_base_model() if hasattr(self.decoder, "get_base_model") else self.decoder
        input_emb_fn = base_decoder.get_input_embeddings()

        start_embeds = input_emb_fn(torch.tensor([self.img_start_id], device=device)).expand(B, 1, -1)
        end_embeds = input_emb_fn(torch.tensor([self.img_end_id], device=device)).expand(B, 1, -1)
        text_embeds = input_emb_fn(input_ids)

        inputs_embeds = torch.cat([start_embeds, vision_embeds, end_embeds, text_embeds], dim=1)

        # 4. Alignment of Labels and Attention Mask
        vision_token_len = inputs_embeds.shape[1] - text_embeds.shape[1]
        
        full_mask = None
        if attention_mask is not None:
            v_mask = torch.ones((B, vision_token_len), device=device, dtype=attention_mask.dtype)
            full_mask = torch.cat([v_mask, attention_mask], dim=1)

        full_labels = None
        if labels is not None:
            vision_ignore = torch.full((B, vision_token_len), -100, device=device)
            full_labels = torch.cat([vision_ignore, labels], dim=1)

        # 5. Decoder Call (Loss is calculated internally by CausalLM)
        return self.decoder(
            inputs_embeds=inputs_embeds,
            attention_mask=full_mask,
            labels=full_labels,
            return_dict=True,
            use_cache=False
        )

# %% [markdown]
# # Dataset

# %%
class RealTextOCRDataset(Dataset):
    def __init__(self, tokenizer, num_samples=20000):
        self.tokenizer = tokenizer
        self.num_samples = num_samples
        self.fake = Faker('en_US')  # English generator

        self.transform = T.Compose([
            T.Resize((1024, 1024), interpolation=T.InterpolationMode.BICUBIC),
            T.ToTensor()
        ]) # do not normalize, DeepSeek-OCR expects [0,1] range

    def __len__(self):
        return self.num_samples

    def generate_content(self):
        # Generate varied content types to make the model robust
        r = random.random()
        if r < 0.4:
            # Type 1: Standard Sentences (The easiest for LLMs)
            return self.fake.sentence(nb_words=10)
        elif r < 0.7:
            # Type 2: Addresses (Structured data)
            return self.fake.address().replace('\n', ', ')
        else:
            # Type 3: Names and Phone numbers
            return f"{self.fake.name()} - {self.fake.phone_number()}"

    def generate_image(self, text):
        # 1. Random Background (White-ish)
        bg_color = random.randint(230, 255)
        img = Image.new('RGB', (1024, 1024), color=(bg_color, bg_color, bg_color))
        draw = ImageDraw.Draw(img)

        # 2. Font Management
        try:
            # Attempt to use a larger, clearer font size
            font_size = random.randint(40, 80)
            font = ImageFont.truetype("/usr/share/fonts/truetype/liberation/LiberationSans-Regular.ttf", font_size)
        except IOError:
            font = ImageFont.load_default()

        # 3. Draw Text (Centered-ish)
        x = random.randint(50, 100)
        y = random.randint(200, 500)

        # Simple text wrapping logic
        words = text.split()
        current_line = ""
        for word in words:
            if (len(current_line) + len(word)) * (font_size * 0.5) > 800:
                draw.text((x, y), current_line, fill=(0, 0, 0), font=font)
                y += font_size + 10
                current_line = word + " "
            else:
                current_line += word + " "

        # Draw the last line
        draw.text((x, y), current_line, fill=(0, 0, 0), font=font)

        return img

    def __getitem__(self, idx):
        text = self.generate_content()
        image = self.generate_image(text)

        pixel_values = self.transform(image)
        # prompt = f"OCR: {text}{self.tokenizer.eos_token}"
        eos = self.tokenizer.eos_token if self.tokenizer.eos_token else "<|endoftext|>"
        prompt = f"OCR: {text}{eos}"

        # Consistent prefix masking logic from Stage 1 setup
        prefix_enc = self.tokenizer("OCR: ", add_special_tokens=False)
        prefix_len = len(prefix_enc.input_ids)

        encodings = self.tokenizer(
            prompt,
            max_length=512,
            truncation=True,
            padding="max_length",
            return_tensors="pt"
        )

        input_ids = encodings.input_ids.squeeze(0)
        attention_mask = encodings.attention_mask.squeeze(0)
        labels = input_ids.clone()

        # Mask prefix and padding
        starts_with_bos = (input_ids[0] == self.tokenizer.bos_token_id)
        offset = 1 if starts_with_bos else 0
        labels[:prefix_len + offset] = -100
        labels[labels == self.tokenizer.pad_token_id] = -100

        return {
            "pixel_values": pixel_values,
            "input_ids": input_ids,
            "attention_mask": attention_mask,
            "labels": labels
        }

# %% [markdown]
# # Training configuration

# %%
DEEPSEEK_OCR_PATH = "deepseek-ai/DeepSeek-OCR"
GOT_PATH = "stepfun-ai/GOT-OCR2_0"
OUTPUT_DIR = "./deepseek_ocr_got_final"

# %%
print(">>> 1. Loading Tokenizer...")
tokenizer = AutoTokenizer.from_pretrained(GOT_PATH, trust_remote_code=True)
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

print(">>> 2. Initializing RealTextOCRDataset...")
train_dataset = RealTextOCRDataset(tokenizer, num_samples=20000)

def collate_fn(batch):
    return {
        "pixel_values": torch.stack([x['pixel_values'] for x in batch]),
        "input_ids": torch.stack([x['input_ids'] for x in batch]),
        "labels": torch.stack([x['labels'] for x in batch]),
        "attention_mask": torch.stack([x['attention_mask'] for x in batch])
    }

print(">>> 3. Initializing Fusion Model...")
model = DeepSeekGOTFusion(
    DEEPSEEK_OCR_PATH,
    GOT_PATH,
    tokenizer,
)
# Out:
# >>> 1. Loading Tokenizer...
# >>> 2. Initializing RealTextOCRDataset...
# >>> 3. Initializing Fusion Model...
# >>> Loading DeepSeek-OCR Encoder...
# You are using a model of type deepseek_vl_v2 to instantiate a model of type DeepseekOCR. This is not supported for all configurations of models and can yield errors.
# Some weights of DeepseekOCRForCausalLM were not initialized from the model checkpoint at deepseek-ai/DeepSeek-OCR and are newly initialized: ['model.vision_model.embeddings.position_ids']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# >>> Loading GOT-OCR Decoder (AutoModel)...
# >>> Injecting LoRA Adapters...
# trainable params: 7,569,408 || all params: 568,098,048 || trainable%: 1.3324

# %%
MAX_STEPS = 500

training_args = TrainingArguments(
    output_dir=OUTPUT_DIR,
    per_device_train_batch_size=1,
    gradient_accumulation_steps=1,
    learning_rate=1e-4,
    max_steps=MAX_STEPS,   # Use max_steps for streaming
    fp16=True,
    gradient_checkpointing=True,
    logging_steps=10,
    save_strategy="steps",
    save_steps=50,
    remove_unused_columns=False,
    report_to="none",
    save_safetensors=False,
    dataloader_pin_memory=False,
    prediction_loss_only=True,
    max_grad_norm=0.5,
    lr_scheduler_type="cosine",
    warmup_steps=5,
    ddp_find_unused_parameters=False,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    data_collator=collate_fn,
)

# %% [markdown]
# # [DEBUG] Sanity Check

# %%
# Set the debug flag
model.debug_one_step = True
model.eval() # Optional: set to eval to disable dropout noise for cleaner check

print(">>> Running Sanity Check...")
# Grab one batch from the dataloader
dataloader = trainer.get_train_dataloader()
batch = next(iter(dataloader))

# Move batch to device
device = model.decoder.device # or "cuda"
batch = {k: v.to(device) for k, v in batch.items() if isinstance(v, torch.Tensor)}

# Forward pass
with torch.no_grad():
    model(**batch)

model.train() # Set back to train mode
print(">>> Sanity Check Complete.")
# Out:
# >>> Running Sanity Check...
#
# [DEBUG] === Alignment Check ===
# [DEBUG] Vision Tokens (N): 272
# [DEBUG] Vision Total (N+2): 274
# [DEBUG] Text Input Length: 512
# [DEBUG] Full Hidden Shape: torch.Size([1, 786, 1024])
# [DEBUG] Relevant Hidden (Sliced): torch.Size([1, 512, 1024])
# [DEBUG] Labels Shape: torch.Size([1, 512])
# [DEBUG] --- Decoding First Sample ---
# [DEBUG] Label Text: ' serious once staff improve break unit way something pattern that husband.'
# [DEBUG] Pred  Text: '.. - - - - - - - - -.'
# [DEBUG] =======================
#
# >>> Sanity Check Complete.

# %% [markdown]
# # Train

# %%
print(">>> 4. Starting Training...")

trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f">>> Trainable Parameters: {trainable_params:,}")

trainer.train()

print(f">>> 5. Saving Projector to {OUTPUT_DIR}...")
model.save_pretrained(OUTPUT_DIR)
print(">>> Done.")
# Out:
# >>> 4. Starting Training...
# >>> Trainable Parameters: 12,293,120
#     <div>
#
#       <progress value='500' max='500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [500/500 09:12, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>10.514500</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>8.337900</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>7.677300</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>7.864300</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>9.959200</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>8.518500</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>6.877700</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>8.569300</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>7.503000</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>7.987800</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>8.095400</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>6.357800</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>6.720500</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>8.762100</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>7.324600</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>6.256700</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>7.731700</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>7.523300</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>6.416400</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>6.422500</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>7.984300</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>6.875500</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>6.416900</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>7.022900</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>5.839700</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>6.133400</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>6.701200</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>6.253300</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>6.383200</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>6.918400</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>6.690900</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>6.606100</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>6.589700</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>6.532300</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>6.567700</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>4.745400</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>6.634300</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>6.172100</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>5.398600</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>5.606300</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>4.609800</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>6.758300</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>6.352500</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>5.386100</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>6.822600</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>5.294300</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>6.153400</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>6.349800</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>5.378300</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>5.338400</td>
#     </tr>
#   </tbody>
# </table><p>
# >>> 5. Saving Projector to ./deepseek_ocr_got_final...
# >>> Done.

# %%
# import torch
# from transformers import AutoModel

# def list_deepseek_components():
#     model_path = "deepseek-ai/DeepSeek-OCR"

#     print(f">>> Loading {model_path} (this may take a moment)...")
#     try:
#         # trust_remote_code=True is required for DeepSeek-OCR
#         model = AutoModel.from_pretrained(
#             model_path,
#             trust_remote_code=True,
#             torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32
#         )
#     except Exception as e:
#         print(f"Error loading model: {e}")
#         return

#     print(f"\n>>> Component List for {model_path}:")
#     print("=" * 60)

#     # Iterate through all named modules (layers/components)
#     for name, module in model.named_modules():
#         # Indent based on depth for readability
#         depth = name.count('.')
#         indent = "  " * depth
#         print(f"{indent}{name} ({module.__class__.__name__})")

#     print("=" * 60)

#     # Specific check for the encoder you were debugging
#     print("\n>>> Checking for Vision Encoder attributes:")
#     if hasattr(model, "deep_encoder"):
#         print("  - Found 'deep_encoder' attribute")
#     elif hasattr(model, "vision_model"):
#         print("  - Found 'vision_model' attribute")
#     else:
#         print("  - Could not find standard 'deep_encoder' or 'vision_model' attributes at top level.")

# if __name__ == "__main__":
#     list_deepseek_components()
# Out:
# >>> Loading deepseek-ai/DeepSeek-OCR (this may take a moment)...
# You are using a model of type deepseek_vl_v2 to instantiate a model of type DeepseekOCR. This is not supported for all configurations of models and can yield errors.
# Some weights of DeepseekOCRForCausalLM were not initialized from the model checkpoint at deepseek-ai/DeepSeek-OCR and are newly initialized: ['model.vision_model.embeddings.position_ids']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# >>> Component List for deepseek-ai/DeepSeek-OCR:
# ============================================================
#  (DeepseekOCRForCausalLM)
# model (DeepseekOCRModel)
#   model.embed_tokens (Embedding)
#   model.layers (ModuleList)
#     model.layers.0 (DeepseekV2DecoderLayer)
#       model.layers.0.self_attn (LlamaAttention)
#         model.layers.0.self_attn.q_proj (Linear)
#         model.layers.0.self_attn.k_proj (Linear)
#         model.layers.0.self_attn.v_proj (Linear)
#         model.layers.0.self_attn.o_proj (Linear)
#       model.layers.0.mlp (DeepseekV2MLP)
#         model.layers.0.mlp.gate_proj (Linear)
#         model.layers.0.mlp.up_proj (Linear)
#         model.layers.0.mlp.down_proj (Linear)
#         model.layers.0.mlp.act_fn (SiLU)
#       model.layers.0.input_layernorm (DeepseekV2RMSNorm)
#       model.layers.0.post_attention_layernorm (DeepseekV2RMSNorm)
#     model.layers.1 (DeepseekV2DecoderLayer)
#       model.layers.1.self_attn (LlamaAttention)
#         model.layers.1.self_attn.q_proj (Linear)
#         model.layers.1.self_attn.k_proj (Linear)
#         model.layers.1.self_attn.v_proj (Linear)
#         model.layers.1.self_attn.o_proj (Linear)
#       model.layers.1.mlp (DeepseekV2MoE)
#         model.layers.1.mlp.experts (ModuleList)
#           model.layers.1.mlp.experts.0 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.0.gate_proj (Linear)
#             model.layers.1.mlp.experts.0.up_proj (Linear)
#             model.layers.1.mlp.experts.0.down_proj (Linear)
#             model.layers.1.mlp.experts.0.act_fn (SiLU)
#           model.layers.1.mlp.experts.1 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.1.gate_proj (Linear)
#             model.layers.1.mlp.experts.1.up_proj (Linear)
#             model.layers.1.mlp.experts.1.down_proj (Linear)
#             model.layers.1.mlp.experts.1.act_fn (SiLU)
#           model.layers.1.mlp.experts.2 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.2.gate_proj (Linear)
#             model.layers.1.mlp.experts.2.up_proj (Linear)
#             model.layers.1.mlp.experts.2.down_proj (Linear)
#             model.layers.1.mlp.experts.2.act_fn (SiLU)
#           model.layers.1.mlp.experts.3 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.3.gate_proj (Linear)
#             model.layers.1.mlp.experts.3.up_proj (Linear)
#             model.layers.1.mlp.experts.3.down_proj (Linear)
#             model.layers.1.mlp.experts.3.act_fn (SiLU)
#           model.layers.1.mlp.experts.4 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.4.gate_proj (Linear)
#             model.layers.1.mlp.experts.4.up_proj (Linear)
#             model.layers.1.mlp.experts.4.down_proj (Linear)
#             model.layers.1.mlp.experts.4.act_fn (SiLU)
#           model.layers.1.mlp.experts.5 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.5.gate_proj (Linear)
#             model.layers.1.mlp.experts.5.up_proj (Linear)
#             model.layers.1.mlp.experts.5.down_proj (Linear)
#             model.layers.1.mlp.experts.5.act_fn (SiLU)
#           model.layers.1.mlp.experts.6 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.6.gate_proj (Linear)
#             model.layers.1.mlp.experts.6.up_proj (Linear)
#             model.layers.1.mlp.experts.6.down_proj (Linear)
#             model.layers.1.mlp.experts.6.act_fn (SiLU)
#           model.layers.1.mlp.experts.7 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.7.gate_proj (Linear)
#             model.layers.1.mlp.experts.7.up_proj (Linear)
#             model.layers.1.mlp.experts.7.down_proj (Linear)
#             model.layers.1.mlp.experts.7.act_fn (SiLU)
#           model.layers.1.mlp.experts.8 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.8.gate_proj (Linear)
#             model.layers.1.mlp.experts.8.up_proj (Linear)
#             model.layers.1.mlp.experts.8.down_proj (Linear)
#             model.layers.1.mlp.experts.8.act_fn (SiLU)
#           model.layers.1.mlp.experts.9 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.9.gate_proj (Linear)
#             model.layers.1.mlp.experts.9.up_proj (Linear)
#             model.layers.1.mlp.experts.9.down_proj (Linear)
#             model.layers.1.mlp.experts.9.act_fn (SiLU)
#           model.layers.1.mlp.experts.10 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.10.gate_proj (Linear)
#             model.layers.1.mlp.experts.10.up_proj (Linear)
#             model.layers.1.mlp.experts.10.down_proj (Linear)
#             model.layers.1.mlp.experts.10.act_fn (SiLU)
#           model.layers.1.mlp.experts.11 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.11.gate_proj (Linear)
#             model.layers.1.mlp.experts.11.up_proj (Linear)
#             model.layers.1.mlp.experts.11.down_proj (Linear)
#             model.layers.1.mlp.experts.11.act_fn (SiLU)
#           model.layers.1.mlp.experts.12 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.12.gate_proj (Linear)
#             model.layers.1.mlp.experts.12.up_proj (Linear)
#             model.layers.1.mlp.experts.12.down_proj (Linear)
#             model.layers.1.mlp.experts.12.act_fn (SiLU)
#           model.layers.1.mlp.experts.13 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.13.gate_proj (Linear)
#             model.layers.1.mlp.experts.13.up_proj (Linear)
#             model.layers.1.mlp.experts.13.down_proj (Linear)
#             model.layers.1.mlp.experts.13.act_fn (SiLU)
#           model.layers.1.mlp.experts.14 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.14.gate_proj (Linear)
#             model.layers.1.mlp.experts.14.up_proj (Linear)
#             model.layers.1.mlp.experts.14.down_proj (Linear)
#             model.layers.1.mlp.experts.14.act_fn (SiLU)
#           model.layers.1.mlp.experts.15 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.15.gate_proj (Linear)
#             model.layers.1.mlp.experts.15.up_proj (Linear)
#             model.layers.1.mlp.experts.15.down_proj (Linear)
#             model.layers.1.mlp.experts.15.act_fn (SiLU)
#           model.layers.1.mlp.experts.16 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.16.gate_proj (Linear)
#             model.layers.1.mlp.experts.16.up_proj (Linear)
#             model.layers.1.mlp.experts.16.down_proj (Linear)
#             model.layers.1.mlp.experts.16.act_fn (SiLU)
#           model.layers.1.mlp.experts.17 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.17.gate_proj (Linear)
#             model.layers.1.mlp.experts.17.up_proj (Linear)
#             model.layers.1.mlp.experts.17.down_proj (Linear)
#             model.layers.1.mlp.experts.17.act_fn (SiLU)
#           model.layers.1.mlp.experts.18 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.18.gate_proj (Linear)
#             model.layers.1.mlp.experts.18.up_proj (Linear)
#             model.layers.1.mlp.experts.18.down_proj (Linear)
#             model.layers.1.mlp.experts.18.act_fn (SiLU)
#           model.layers.1.mlp.experts.19 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.19.gate_proj (Linear)
#             model.layers.1.mlp.experts.19.up_proj (Linear)
#             model.layers.1.mlp.experts.19.down_proj (Linear)
#             model.layers.1.mlp.experts.19.act_fn (SiLU)
#           model.layers.1.mlp.experts.20 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.20.gate_proj (Linear)
#             model.layers.1.mlp.experts.20.up_proj (Linear)
#             model.layers.1.mlp.experts.20.down_proj (Linear)
#             model.layers.1.mlp.experts.20.act_fn (SiLU)
#           model.layers.1.mlp.experts.21 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.21.gate_proj (Linear)
#             model.layers.1.mlp.experts.21.up_proj (Linear)
#             model.layers.1.mlp.experts.21.down_proj (Linear)
#             model.layers.1.mlp.experts.21.act_fn (SiLU)
#           model.layers.1.mlp.experts.22 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.22.gate_proj (Linear)
#             model.layers.1.mlp.experts.22.up_proj (Linear)
#             model.layers.1.mlp.experts.22.down_proj (Linear)
#             model.layers.1.mlp.experts.22.act_fn (SiLU)
#           model.layers.1.mlp.experts.23 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.23.gate_proj (Linear)
#             model.layers.1.mlp.experts.23.up_proj (Linear)
#             model.layers.1.mlp.experts.23.down_proj (Linear)
#             model.layers.1.mlp.experts.23.act_fn (SiLU)
#           model.layers.1.mlp.experts.24 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.24.gate_proj (Linear)
#             model.layers.1.mlp.experts.24.up_proj (Linear)
#             model.layers.1.mlp.experts.24.down_proj (Linear)
#             model.layers.1.mlp.experts.24.act_fn (SiLU)
#           model.layers.1.mlp.experts.25 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.25.gate_proj (Linear)
#             model.layers.1.mlp.experts.25.up_proj (Linear)
#             model.layers.1.mlp.experts.25.down_proj (Linear)
#             model.layers.1.mlp.experts.25.act_fn (SiLU)
#           model.layers.1.mlp.experts.26 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.26.gate_proj (Linear)
#             model.layers.1.mlp.experts.26.up_proj (Linear)
#             model.layers.1.mlp.experts.26.down_proj (Linear)
#             model.layers.1.mlp.experts.26.act_fn (SiLU)
#           model.layers.1.mlp.experts.27 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.27.gate_proj (Linear)
#             model.layers.1.mlp.experts.27.up_proj (Linear)
#             model.layers.1.mlp.experts.27.down_proj (Linear)
#             model.layers.1.mlp.experts.27.act_fn (SiLU)
#           model.layers.1.mlp.experts.28 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.28.gate_proj (Linear)
#             model.layers.1.mlp.experts.28.up_proj (Linear)
#             model.layers.1.mlp.experts.28.down_proj (Linear)
#             model.layers.1.mlp.experts.28.act_fn (SiLU)
#           model.layers.1.mlp.experts.29 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.29.gate_proj (Linear)
#             model.layers.1.mlp.experts.29.up_proj (Linear)
#             model.layers.1.mlp.experts.29.down_proj (Linear)
#             model.layers.1.mlp.experts.29.act_fn (SiLU)
#           model.layers.1.mlp.experts.30 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.30.gate_proj (Linear)
#             model.layers.1.mlp.experts.30.up_proj (Linear)
#             model.layers.1.mlp.experts.30.down_proj (Linear)
#             model.layers.1.mlp.experts.30.act_fn (SiLU)
#           model.layers.1.mlp.experts.31 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.31.gate_proj (Linear)
#             model.layers.1.mlp.experts.31.up_proj (Linear)
#             model.layers.1.mlp.experts.31.down_proj (Linear)
#             model.layers.1.mlp.experts.31.act_fn (SiLU)
#           model.layers.1.mlp.experts.32 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.32.gate_proj (Linear)
#             model.layers.1.mlp.experts.32.up_proj (Linear)
#             model.layers.1.mlp.experts.32.down_proj (Linear)
#             model.layers.1.mlp.experts.32.act_fn (SiLU)
#           model.layers.1.mlp.experts.33 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.33.gate_proj (Linear)
#             model.layers.1.mlp.experts.33.up_proj (Linear)
#             model.layers.1.mlp.experts.33.down_proj (Linear)
#             model.layers.1.mlp.experts.33.act_fn (SiLU)
#           model.layers.1.mlp.experts.34 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.34.gate_proj (Linear)
#             model.layers.1.mlp.experts.34.up_proj (Linear)
#             model.layers.1.mlp.experts.34.down_proj (Linear)
#             model.layers.1.mlp.experts.34.act_fn (SiLU)
#           model.layers.1.mlp.experts.35 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.35.gate_proj (Linear)
#             model.layers.1.mlp.experts.35.up_proj (Linear)
#             model.layers.1.mlp.experts.35.down_proj (Linear)
#             model.layers.1.mlp.experts.35.act_fn (SiLU)
#           model.layers.1.mlp.experts.36 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.36.gate_proj (Linear)
#             model.layers.1.mlp.experts.36.up_proj (Linear)
#             model.layers.1.mlp.experts.36.down_proj (Linear)
#             model.layers.1.mlp.experts.36.act_fn (SiLU)
#           model.layers.1.mlp.experts.37 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.37.gate_proj (Linear)
#             model.layers.1.mlp.experts.37.up_proj (Linear)
#             model.layers.1.mlp.experts.37.down_proj (Linear)
#             model.layers.1.mlp.experts.37.act_fn (SiLU)
#           model.layers.1.mlp.experts.38 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.38.gate_proj (Linear)
#             model.layers.1.mlp.experts.38.up_proj (Linear)
#             model.layers.1.mlp.experts.38.down_proj (Linear)
#             model.layers.1.mlp.experts.38.act_fn (SiLU)
#           model.layers.1.mlp.experts.39 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.39.gate_proj (Linear)
#             model.layers.1.mlp.experts.39.up_proj (Linear)
#             model.layers.1.mlp.experts.39.down_proj (Linear)
#             model.layers.1.mlp.experts.39.act_fn (SiLU)
#           model.layers.1.mlp.experts.40 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.40.gate_proj (Linear)
#             model.layers.1.mlp.experts.40.up_proj (Linear)
#             model.layers.1.mlp.experts.40.down_proj (Linear)
#             model.layers.1.mlp.experts.40.act_fn (SiLU)
#           model.layers.1.mlp.experts.41 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.41.gate_proj (Linear)
#             model.layers.1.mlp.experts.41.up_proj (Linear)
#             model.layers.1.mlp.experts.41.down_proj (Linear)
#             model.layers.1.mlp.experts.41.act_fn (SiLU)
#           model.layers.1.mlp.experts.42 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.42.gate_proj (Linear)
#             model.layers.1.mlp.experts.42.up_proj (Linear)
#             model.layers.1.mlp.experts.42.down_proj (Linear)
#             model.layers.1.mlp.experts.42.act_fn (SiLU)
#           model.layers.1.mlp.experts.43 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.43.gate_proj (Linear)
#             model.layers.1.mlp.experts.43.up_proj (Linear)
#             model.layers.1.mlp.experts.43.down_proj (Linear)
#             model.layers.1.mlp.experts.43.act_fn (SiLU)
#           model.layers.1.mlp.experts.44 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.44.gate_proj (Linear)
#             model.layers.1.mlp.experts.44.up_proj (Linear)
#             model.layers.1.mlp.experts.44.down_proj (Linear)
#             model.layers.1.mlp.experts.44.act_fn (SiLU)
#           model.layers.1.mlp.experts.45 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.45.gate_proj (Linear)
#             model.layers.1.mlp.experts.45.up_proj (Linear)
#             model.layers.1.mlp.experts.45.down_proj (Linear)
#             model.layers.1.mlp.experts.45.act_fn (SiLU)
#           model.layers.1.mlp.experts.46 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.46.gate_proj (Linear)
#             model.layers.1.mlp.experts.46.up_proj (Linear)
#             model.layers.1.mlp.experts.46.down_proj (Linear)
#             model.layers.1.mlp.experts.46.act_fn (SiLU)
#           model.layers.1.mlp.experts.47 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.47.gate_proj (Linear)
#             model.layers.1.mlp.experts.47.up_proj (Linear)
#             model.layers.1.mlp.experts.47.down_proj (Linear)
#             model.layers.1.mlp.experts.47.act_fn (SiLU)
#           model.layers.1.mlp.experts.48 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.48.gate_proj (Linear)
#             model.layers.1.mlp.experts.48.up_proj (Linear)
#             model.layers.1.mlp.experts.48.down_proj (Linear)
#             model.layers.1.mlp.experts.48.act_fn (SiLU)
#           model.layers.1.mlp.experts.49 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.49.gate_proj (Linear)
#             model.layers.1.mlp.experts.49.up_proj (Linear)
#             model.layers.1.mlp.experts.49.down_proj (Linear)
#             model.layers.1.mlp.experts.49.act_fn (SiLU)
#           model.layers.1.mlp.experts.50 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.50.gate_proj (Linear)
#             model.layers.1.mlp.experts.50.up_proj (Linear)
#             model.layers.1.mlp.experts.50.down_proj (Linear)
#             model.layers.1.mlp.experts.50.act_fn (SiLU)
#           model.layers.1.mlp.experts.51 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.51.gate_proj (Linear)
#             model.layers.1.mlp.experts.51.up_proj (Linear)
#             model.layers.1.mlp.experts.51.down_proj (Linear)
#             model.layers.1.mlp.experts.51.act_fn (SiLU)
#           model.layers.1.mlp.experts.52 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.52.gate_proj (Linear)
#             model.layers.1.mlp.experts.52.up_proj (Linear)
#             model.layers.1.mlp.experts.52.down_proj (Linear)
#             model.layers.1.mlp.experts.52.act_fn (SiLU)
#           model.layers.1.mlp.experts.53 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.53.gate_proj (Linear)
#             model.layers.1.mlp.experts.53.up_proj (Linear)
#             model.layers.1.mlp.experts.53.down_proj (Linear)
#             model.layers.1.mlp.experts.53.act_fn (SiLU)
#           model.layers.1.mlp.experts.54 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.54.gate_proj (Linear)
#             model.layers.1.mlp.experts.54.up_proj (Linear)
#             model.layers.1.mlp.experts.54.down_proj (Linear)
#             model.layers.1.mlp.experts.54.act_fn (SiLU)
#           model.layers.1.mlp.experts.55 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.55.gate_proj (Linear)
#             model.layers.1.mlp.experts.55.up_proj (Linear)
#             model.layers.1.mlp.experts.55.down_proj (Linear)
#             model.layers.1.mlp.experts.55.act_fn (SiLU)
#           model.layers.1.mlp.experts.56 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.56.gate_proj (Linear)
#             model.layers.1.mlp.experts.56.up_proj (Linear)
#             model.layers.1.mlp.experts.56.down_proj (Linear)
#             model.layers.1.mlp.experts.56.act_fn (SiLU)
#           model.layers.1.mlp.experts.57 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.57.gate_proj (Linear)
#             model.layers.1.mlp.experts.57.up_proj (Linear)
#             model.layers.1.mlp.experts.57.down_proj (Linear)
#             model.layers.1.mlp.experts.57.act_fn (SiLU)
#           model.layers.1.mlp.experts.58 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.58.gate_proj (Linear)
#             model.layers.1.mlp.experts.58.up_proj (Linear)
#             model.layers.1.mlp.experts.58.down_proj (Linear)
#             model.layers.1.mlp.experts.58.act_fn (SiLU)
#           model.layers.1.mlp.experts.59 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.59.gate_proj (Linear)
#             model.layers.1.mlp.experts.59.up_proj (Linear)
#             model.layers.1.mlp.experts.59.down_proj (Linear)
#             model.layers.1.mlp.experts.59.act_fn (SiLU)
#           model.layers.1.mlp.experts.60 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.60.gate_proj (Linear)
#             model.layers.1.mlp.experts.60.up_proj (Linear)
#             model.layers.1.mlp.experts.60.down_proj (Linear)
#             model.layers.1.mlp.experts.60.act_fn (SiLU)
#           model.layers.1.mlp.experts.61 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.61.gate_proj (Linear)
#             model.layers.1.mlp.experts.61.up_proj (Linear)
#             model.layers.1.mlp.experts.61.down_proj (Linear)
#             model.layers.1.mlp.experts.61.act_fn (SiLU)
#           model.layers.1.mlp.experts.62 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.62.gate_proj (Linear)
#             model.layers.1.mlp.experts.62.up_proj (Linear)
#             model.layers.1.mlp.experts.62.down_proj (Linear)
#             model.layers.1.mlp.experts.62.act_fn (SiLU)
#           model.layers.1.mlp.experts.63 (DeepseekV2MLP)
#             model.layers.1.mlp.experts.63.gate_proj (Linear)
#             model.layers.1.mlp.experts.63.up_proj (Linear)
#             model.layers.1.mlp.experts.63.down_proj (Linear)
#             model.layers.1.mlp.experts.63.act_fn (SiLU)
#         model.layers.1.mlp.gate (MoEGate)
#         model.layers.1.mlp.shared_experts (DeepseekV2MLP)
#           model.layers.1.mlp.shared_experts.gate_proj (Linear)
#           model.layers.1.mlp.shared_experts.up_proj (Linear)
#           model.layers.1.mlp.shared_experts.down_proj (Linear)
#           model.layers.1.mlp.shared_experts.act_fn (SiLU)
#       model.layers.1.input_layernorm (DeepseekV2RMSNorm)
#       model.layers.1.post_attention_layernorm (DeepseekV2RMSNorm)
#     model.layers.2 (DeepseekV2DecoderLayer)
#       model.layers.2.self_attn (LlamaAttention)
#         model.layers.2.self_attn.q_proj (Linear)
#         model.layers.2.self_attn.k_proj (Linear)
#         model.layers.2.self_attn.v_proj (Linear)
#         model.layers.2.self_attn.o_proj (Linear)
#       model.layers.2.mlp (DeepseekV2MoE)
#         model.layers.2.mlp.experts (ModuleList)
#           model.layers.2.mlp.experts.0 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.0.gate_proj (Linear)
#             model.layers.2.mlp.experts.0.up_proj (Linear)
#             model.layers.2.mlp.experts.0.down_proj (Linear)
#             model.layers.2.mlp.experts.0.act_fn (SiLU)
#           model.layers.2.mlp.experts.1 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.1.gate_proj (Linear)
#             model.layers.2.mlp.experts.1.up_proj (Linear)
#             model.layers.2.mlp.experts.1.down_proj (Linear)
#             model.layers.2.mlp.experts.1.act_fn (SiLU)
#           model.layers.2.mlp.experts.2 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.2.gate_proj (Linear)
#             model.layers.2.mlp.experts.2.up_proj (Linear)
#             model.layers.2.mlp.experts.2.down_proj (Linear)
#             model.layers.2.mlp.experts.2.act_fn (SiLU)
#           model.layers.2.mlp.experts.3 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.3.gate_proj (Linear)
#             model.layers.2.mlp.experts.3.up_proj (Linear)
#             model.layers.2.mlp.experts.3.down_proj (Linear)
#             model.layers.2.mlp.experts.3.act_fn (SiLU)
#           model.layers.2.mlp.experts.4 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.4.gate_proj (Linear)
#             model.layers.2.mlp.experts.4.up_proj (Linear)
#             model.layers.2.mlp.experts.4.down_proj (Linear)
#             model.layers.2.mlp.experts.4.act_fn (SiLU)
#           model.layers.2.mlp.experts.5 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.5.gate_proj (Linear)
#             model.layers.2.mlp.experts.5.up_proj (Linear)
#             model.layers.2.mlp.experts.5.down_proj (Linear)
#             model.layers.2.mlp.experts.5.act_fn (SiLU)
#           model.layers.2.mlp.experts.6 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.6.gate_proj (Linear)
#             model.layers.2.mlp.experts.6.up_proj (Linear)
#             model.layers.2.mlp.experts.6.down_proj (Linear)
#             model.layers.2.mlp.experts.6.act_fn (SiLU)
#           model.layers.2.mlp.experts.7 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.7.gate_proj (Linear)
#             model.layers.2.mlp.experts.7.up_proj (Linear)
#             model.layers.2.mlp.experts.7.down_proj (Linear)
#             model.layers.2.mlp.experts.7.act_fn (SiLU)
#           model.layers.2.mlp.experts.8 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.8.gate_proj (Linear)
#             model.layers.2.mlp.experts.8.up_proj (Linear)
#             model.layers.2.mlp.experts.8.down_proj (Linear)
#             model.layers.2.mlp.experts.8.act_fn (SiLU)
#           model.layers.2.mlp.experts.9 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.9.gate_proj (Linear)
#             model.layers.2.mlp.experts.9.up_proj (Linear)
#             model.layers.2.mlp.experts.9.down_proj (Linear)
#             model.layers.2.mlp.experts.9.act_fn (SiLU)
#           model.layers.2.mlp.experts.10 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.10.gate_proj (Linear)
#             model.layers.2.mlp.experts.10.up_proj (Linear)
#             model.layers.2.mlp.experts.10.down_proj (Linear)
#             model.layers.2.mlp.experts.10.act_fn (SiLU)
#           model.layers.2.mlp.experts.11 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.11.gate_proj (Linear)
#             model.layers.2.mlp.experts.11.up_proj (Linear)
#             model.layers.2.mlp.experts.11.down_proj (Linear)
#             model.layers.2.mlp.experts.11.act_fn (SiLU)
#           model.layers.2.mlp.experts.12 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.12.gate_proj (Linear)
#             model.layers.2.mlp.experts.12.up_proj (Linear)
#             model.layers.2.mlp.experts.12.down_proj (Linear)
#             model.layers.2.mlp.experts.12.act_fn (SiLU)
#           model.layers.2.mlp.experts.13 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.13.gate_proj (Linear)
#             model.layers.2.mlp.experts.13.up_proj (Linear)
#             model.layers.2.mlp.experts.13.down_proj (Linear)
#             model.layers.2.mlp.experts.13.act_fn (SiLU)
#           model.layers.2.mlp.experts.14 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.14.gate_proj (Linear)
#             model.layers.2.mlp.experts.14.up_proj (Linear)
#             model.layers.2.mlp.experts.14.down_proj (Linear)
#             model.layers.2.mlp.experts.14.act_fn (SiLU)
#           model.layers.2.mlp.experts.15 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.15.gate_proj (Linear)
#             model.layers.2.mlp.experts.15.up_proj (Linear)
#             model.layers.2.mlp.experts.15.down_proj (Linear)
#             model.layers.2.mlp.experts.15.act_fn (SiLU)
#           model.layers.2.mlp.experts.16 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.16.gate_proj (Linear)
#             model.layers.2.mlp.experts.16.up_proj (Linear)
#             model.layers.2.mlp.experts.16.down_proj (Linear)
#             model.layers.2.mlp.experts.16.act_fn (SiLU)
#           model.layers.2.mlp.experts.17 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.17.gate_proj (Linear)
#             model.layers.2.mlp.experts.17.up_proj (Linear)
#             model.layers.2.mlp.experts.17.down_proj (Linear)
#             model.layers.2.mlp.experts.17.act_fn (SiLU)
#           model.layers.2.mlp.experts.18 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.18.gate_proj (Linear)
#             model.layers.2.mlp.experts.18.up_proj (Linear)
#             model.layers.2.mlp.experts.18.down_proj (Linear)
#             model.layers.2.mlp.experts.18.act_fn (SiLU)
#           model.layers.2.mlp.experts.19 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.19.gate_proj (Linear)
#             model.layers.2.mlp.experts.19.up_proj (Linear)
#             model.layers.2.mlp.experts.19.down_proj (Linear)
#             model.layers.2.mlp.experts.19.act_fn (SiLU)
#           model.layers.2.mlp.experts.20 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.20.gate_proj (Linear)
#             model.layers.2.mlp.experts.20.up_proj (Linear)
#             model.layers.2.mlp.experts.20.down_proj (Linear)
#             model.layers.2.mlp.experts.20.act_fn (SiLU)
#           model.layers.2.mlp.experts.21 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.21.gate_proj (Linear)
#             model.layers.2.mlp.experts.21.up_proj (Linear)
#             model.layers.2.mlp.experts.21.down_proj (Linear)
#             model.layers.2.mlp.experts.21.act_fn (SiLU)
#           model.layers.2.mlp.experts.22 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.22.gate_proj (Linear)
#             model.layers.2.mlp.experts.22.up_proj (Linear)
#             model.layers.2.mlp.experts.22.down_proj (Linear)
#             model.layers.2.mlp.experts.22.act_fn (SiLU)
#           model.layers.2.mlp.experts.23 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.23.gate_proj (Linear)
#             model.layers.2.mlp.experts.23.up_proj (Linear)
#             model.layers.2.mlp.experts.23.down_proj (Linear)
#             model.layers.2.mlp.experts.23.act_fn (SiLU)
#           model.layers.2.mlp.experts.24 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.24.gate_proj (Linear)
#             model.layers.2.mlp.experts.24.up_proj (Linear)
#             model.layers.2.mlp.experts.24.down_proj (Linear)
#             model.layers.2.mlp.experts.24.act_fn (SiLU)
#           model.layers.2.mlp.experts.25 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.25.gate_proj (Linear)
#             model.layers.2.mlp.experts.25.up_proj (Linear)
#             model.layers.2.mlp.experts.25.down_proj (Linear)
#             model.layers.2.mlp.experts.25.act_fn (SiLU)
#           model.layers.2.mlp.experts.26 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.26.gate_proj (Linear)
#             model.layers.2.mlp.experts.26.up_proj (Linear)
#             model.layers.2.mlp.experts.26.down_proj (Linear)
#             model.layers.2.mlp.experts.26.act_fn (SiLU)
#           model.layers.2.mlp.experts.27 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.27.gate_proj (Linear)
#             model.layers.2.mlp.experts.27.up_proj (Linear)
#             model.layers.2.mlp.experts.27.down_proj (Linear)
#             model.layers.2.mlp.experts.27.act_fn (SiLU)
#           model.layers.2.mlp.experts.28 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.28.gate_proj (Linear)
#             model.layers.2.mlp.experts.28.up_proj (Linear)
#             model.layers.2.mlp.experts.28.down_proj (Linear)
#             model.layers.2.mlp.experts.28.act_fn (SiLU)
#           model.layers.2.mlp.experts.29 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.29.gate_proj (Linear)
#             model.layers.2.mlp.experts.29.up_proj (Linear)
#             model.layers.2.mlp.experts.29.down_proj (Linear)
#             model.layers.2.mlp.experts.29.act_fn (SiLU)
#           model.layers.2.mlp.experts.30 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.30.gate_proj (Linear)
#             model.layers.2.mlp.experts.30.up_proj (Linear)
#             model.layers.2.mlp.experts.30.down_proj (Linear)
#             model.layers.2.mlp.experts.30.act_fn (SiLU)
#           model.layers.2.mlp.experts.31 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.31.gate_proj (Linear)
#             model.layers.2.mlp.experts.31.up_proj (Linear)
#             model.layers.2.mlp.experts.31.down_proj (Linear)
#             model.layers.2.mlp.experts.31.act_fn (SiLU)
#           model.layers.2.mlp.experts.32 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.32.gate_proj (Linear)
#             model.layers.2.mlp.experts.32.up_proj (Linear)
#             model.layers.2.mlp.experts.32.down_proj (Linear)
#             model.layers.2.mlp.experts.32.act_fn (SiLU)
#           model.layers.2.mlp.experts.33 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.33.gate_proj (Linear)
#             model.layers.2.mlp.experts.33.up_proj (Linear)
#             model.layers.2.mlp.experts.33.down_proj (Linear)
#             model.layers.2.mlp.experts.33.act_fn (SiLU)
#           model.layers.2.mlp.experts.34 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.34.gate_proj (Linear)
#             model.layers.2.mlp.experts.34.up_proj (Linear)
#             model.layers.2.mlp.experts.34.down_proj (Linear)
#             model.layers.2.mlp.experts.34.act_fn (SiLU)
#           model.layers.2.mlp.experts.35 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.35.gate_proj (Linear)
#             model.layers.2.mlp.experts.35.up_proj (Linear)
#             model.layers.2.mlp.experts.35.down_proj (Linear)
#             model.layers.2.mlp.experts.35.act_fn (SiLU)
#           model.layers.2.mlp.experts.36 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.36.gate_proj (Linear)
#             model.layers.2.mlp.experts.36.up_proj (Linear)
#             model.layers.2.mlp.experts.36.down_proj (Linear)
#             model.layers.2.mlp.experts.36.act_fn (SiLU)
#           model.layers.2.mlp.experts.37 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.37.gate_proj (Linear)
#             model.layers.2.mlp.experts.37.up_proj (Linear)
#             model.layers.2.mlp.experts.37.down_proj (Linear)
#             model.layers.2.mlp.experts.37.act_fn (SiLU)
#           model.layers.2.mlp.experts.38 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.38.gate_proj (Linear)
#             model.layers.2.mlp.experts.38.up_proj (Linear)
#             model.layers.2.mlp.experts.38.down_proj (Linear)
#             model.layers.2.mlp.experts.38.act_fn (SiLU)
#           model.layers.2.mlp.experts.39 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.39.gate_proj (Linear)
#             model.layers.2.mlp.experts.39.up_proj (Linear)
#             model.layers.2.mlp.experts.39.down_proj (Linear)
#             model.layers.2.mlp.experts.39.act_fn (SiLU)
#           model.layers.2.mlp.experts.40 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.40.gate_proj (Linear)
#             model.layers.2.mlp.experts.40.up_proj (Linear)
#             model.layers.2.mlp.experts.40.down_proj (Linear)
#             model.layers.2.mlp.experts.40.act_fn (SiLU)
#           model.layers.2.mlp.experts.41 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.41.gate_proj (Linear)
#             model.layers.2.mlp.experts.41.up_proj (Linear)
#             model.layers.2.mlp.experts.41.down_proj (Linear)
#             model.layers.2.mlp.experts.41.act_fn (SiLU)
#           model.layers.2.mlp.experts.42 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.42.gate_proj (Linear)
#             model.layers.2.mlp.experts.42.up_proj (Linear)
#             model.layers.2.mlp.experts.42.down_proj (Linear)
#             model.layers.2.mlp.experts.42.act_fn (SiLU)
#           model.layers.2.mlp.experts.43 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.43.gate_proj (Linear)
#             model.layers.2.mlp.experts.43.up_proj (Linear)
#             model.layers.2.mlp.experts.43.down_proj (Linear)
#             model.layers.2.mlp.experts.43.act_fn (SiLU)
#           model.layers.2.mlp.experts.44 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.44.gate_proj (Linear)
#             model.layers.2.mlp.experts.44.up_proj (Linear)
#             model.layers.2.mlp.experts.44.down_proj (Linear)
#             model.layers.2.mlp.experts.44.act_fn (SiLU)
#           model.layers.2.mlp.experts.45 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.45.gate_proj (Linear)
#             model.layers.2.mlp.experts.45.up_proj (Linear)
#             model.layers.2.mlp.experts.45.down_proj (Linear)
#             model.layers.2.mlp.experts.45.act_fn (SiLU)
#           model.layers.2.mlp.experts.46 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.46.gate_proj (Linear)
#             model.layers.2.mlp.experts.46.up_proj (Linear)
#             model.layers.2.mlp.experts.46.down_proj (Linear)
#             model.layers.2.mlp.experts.46.act_fn (SiLU)
#           model.layers.2.mlp.experts.47 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.47.gate_proj (Linear)
#             model.layers.2.mlp.experts.47.up_proj (Linear)
#             model.layers.2.mlp.experts.47.down_proj (Linear)
#             model.layers.2.mlp.experts.47.act_fn (SiLU)
#           model.layers.2.mlp.experts.48 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.48.gate_proj (Linear)
#             model.layers.2.mlp.experts.48.up_proj (Linear)
#             model.layers.2.mlp.experts.48.down_proj (Linear)
#             model.layers.2.mlp.experts.48.act_fn (SiLU)
#           model.layers.2.mlp.experts.49 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.49.gate_proj (Linear)
#             model.layers.2.mlp.experts.49.up_proj (Linear)
#             model.layers.2.mlp.experts.49.down_proj (Linear)
#             model.layers.2.mlp.experts.49.act_fn (SiLU)
#           model.layers.2.mlp.experts.50 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.50.gate_proj (Linear)
#             model.layers.2.mlp.experts.50.up_proj (Linear)
#             model.layers.2.mlp.experts.50.down_proj (Linear)
#             model.layers.2.mlp.experts.50.act_fn (SiLU)
#           model.layers.2.mlp.experts.51 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.51.gate_proj (Linear)
#             model.layers.2.mlp.experts.51.up_proj (Linear)
#             model.layers.2.mlp.experts.51.down_proj (Linear)
#             model.layers.2.mlp.experts.51.act_fn (SiLU)
#           model.layers.2.mlp.experts.52 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.52.gate_proj (Linear)
#             model.layers.2.mlp.experts.52.up_proj (Linear)
#             model.layers.2.mlp.experts.52.down_proj (Linear)
#             model.layers.2.mlp.experts.52.act_fn (SiLU)
#           model.layers.2.mlp.experts.53 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.53.gate_proj (Linear)
#             model.layers.2.mlp.experts.53.up_proj (Linear)
#             model.layers.2.mlp.experts.53.down_proj (Linear)
#             model.layers.2.mlp.experts.53.act_fn (SiLU)
#           model.layers.2.mlp.experts.54 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.54.gate_proj (Linear)
#             model.layers.2.mlp.experts.54.up_proj (Linear)
#             model.layers.2.mlp.experts.54.down_proj (Linear)
#             model.layers.2.mlp.experts.54.act_fn (SiLU)
#           model.layers.2.mlp.experts.55 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.55.gate_proj (Linear)
#             model.layers.2.mlp.experts.55.up_proj (Linear)
#             model.layers.2.mlp.experts.55.down_proj (Linear)
#             model.layers.2.mlp.experts.55.act_fn (SiLU)
#           model.layers.2.mlp.experts.56 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.56.gate_proj (Linear)
#             model.layers.2.mlp.experts.56.up_proj (Linear)
#             model.layers.2.mlp.experts.56.down_proj (Linear)
#             model.layers.2.mlp.experts.56.act_fn (SiLU)
#           model.layers.2.mlp.experts.57 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.57.gate_proj (Linear)
#             model.layers.2.mlp.experts.57.up_proj (Linear)
#             model.layers.2.mlp.experts.57.down_proj (Linear)
#             model.layers.2.mlp.experts.57.act_fn (SiLU)
#           model.layers.2.mlp.experts.58 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.58.gate_proj (Linear)
#             model.layers.2.mlp.experts.58.up_proj (Linear)
#             model.layers.2.mlp.experts.58.down_proj (Linear)
#             model.layers.2.mlp.experts.58.act_fn (SiLU)
#           model.layers.2.mlp.experts.59 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.59.gate_proj (Linear)
#             model.layers.2.mlp.experts.59.up_proj (Linear)
#             model.layers.2.mlp.experts.59.down_proj (Linear)
#             model.layers.2.mlp.experts.59.act_fn (SiLU)
#           model.layers.2.mlp.experts.60 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.60.gate_proj (Linear)
#             model.layers.2.mlp.experts.60.up_proj (Linear)
#             model.layers.2.mlp.experts.60.down_proj (Linear)
#             model.layers.2.mlp.experts.60.act_fn (SiLU)
#           model.layers.2.mlp.experts.61 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.61.gate_proj (Linear)
#             model.layers.2.mlp.experts.61.up_proj (Linear)
#             model.layers.2.mlp.experts.61.down_proj (Linear)
#             model.layers.2.mlp.experts.61.act_fn (SiLU)
#           model.layers.2.mlp.experts.62 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.62.gate_proj (Linear)
#             model.layers.2.mlp.experts.62.up_proj (Linear)
#             model.layers.2.mlp.experts.62.down_proj (Linear)
#             model.layers.2.mlp.experts.62.act_fn (SiLU)
#           model.layers.2.mlp.experts.63 (DeepseekV2MLP)
#             model.layers.2.mlp.experts.63.gate_proj (Linear)
#             model.layers.2.mlp.experts.63.up_proj (Linear)
#             model.layers.2.mlp.experts.63.down_proj (Linear)
#             model.layers.2.mlp.experts.63.act_fn (SiLU)
#         model.layers.2.mlp.gate (MoEGate)
#         model.layers.2.mlp.shared_experts (DeepseekV2MLP)
#           model.layers.2.mlp.shared_experts.gate_proj (Linear)
#           model.layers.2.mlp.shared_experts.up_proj (Linear)
#           model.layers.2.mlp.shared_experts.down_proj (Linear)
#           model.layers.2.mlp.shared_experts.act_fn (SiLU)
#       model.layers.2.input_layernorm (DeepseekV2RMSNorm)
#       model.layers.2.post_attention_layernorm (DeepseekV2RMSNorm)
#     model.layers.3 (DeepseekV2DecoderLayer)
#       model.layers.3.self_attn (LlamaAttention)
#         model.layers.3.self_attn.q_proj (Linear)
#         model.layers.3.self_attn.k_proj (Linear)
#         model.layers.3.self_attn.v_proj (Linear)
#         model.layers.3.self_attn.o_proj (Linear)
#       model.layers.3.mlp (DeepseekV2MoE)
#         model.layers.3.mlp.experts (ModuleList)
#           model.layers.3.mlp.experts.0 (DeepseekV2MLP)
#             model.layers.3.mlp.experts.0.gate_proj (Linear)
#             model.layers.3.mlp.experts.0.up_proj (Linear)
#             model.layers.3.mlp.experts.0.down_proj (Linear)
#             model.layers.3.mlp.experts.0.act_fn (SiLU)
#           model.layers.3.mlp.experts.1 (DeepseekV2MLP)
#             model.layers.3.mlp.experts.1.gate_proj (Linear)
#             model.layers.3.mlp.experts.1.up_proj (Linear)
#             model.layers.3.mlp.experts.1.down_proj (Linear)
#             model.layers.3.mlp.experts.1.act_fn (SiLU)
#           model.layers.3.mlp.experts.2 (DeepseekV2MLP)
#             model.layers.3.mlp.experts.2.gate_proj (Linear)
#             model.layers.3.mlp.experts.2.up_proj (Linear)
#             model.layers.3.mlp.experts.2.down_proj (Linear)
#             model.layers.3.mlp.experts.2.act_fn (SiLU)
#           model.layers.3.mlp.experts.3 (DeepseekV2MLP)
#             model.layers.3.mlp.experts.3.gate_proj (Linear)
#             model.layers.3.mlp.experts.3.up_proj (Linear)
#             model.layers.3.mlp.experts.3.down_proj (Linear)
#             model.layers.3.mlp.experts.3.act_fn (SiLU)
#           model.layers.3.mlp.experts.4 (DeepseekV2MLP)
#             model.layers.3.mlp.experts.4.gate_proj (Linear)
#             model.layers.3.mlp.experts.4.up_proj (Linear)
#             model.layers.3.mlp.experts.4.down_proj (Linear)
#             model.layers.3.mlp.experts.4.act_fn (SiLU)
#           model.layers.3.mlp.experts.5 (DeepseekV2MLP)
#             model.layers.3.mlp.experts.5.gate_proj (Linear)
#             model.layers.3.mlp.experts.5.up_proj (Linear)
#             model.layers.3.mlp.experts.5.down_proj (Linear)
#             model.layers.3.mlp.experts.5.act_fn (SiLU)
#           model.layers.3.mlp.experts.6 (DeepseekV2MLP)
#             model.layers.3.mlp.experts.6.gate_proj (Linear)
#             model.layers.3.mlp.experts.6.up_proj (Linear)
#             model.layers.3.mlp.experts.6.down_proj (Linear)
#             model.layers.3.mlp.experts.6.act_fn (SiLU)
#           model.layers.3.mlp.experts.7 (DeepseekV2MLP)
#             model.layers.3.mlp.experts.7.gate_proj (Linear)
#             model.layers.3.mlp.experts.7.up_proj (Linear)
#             model.layers.3.mlp.experts.7.down_proj (Linear)
#             model.layers.3.mlp.experts.7.act_fn (SiLU)
#           model.layers.3.mlp.experts.8 (DeepseekV2MLP)
#             model.layers.3.mlp.experts.8.gate_proj (Linear)
#             model.layers.3.mlp.experts.8.up_proj (Linear)
#             model.layers.3.mlp.experts.8.down_proj (Linear)
#             model.layers.3.mlp.experts.8.act_fn (SiLU)
#           model.layers.3.mlp.experts.9 (DeepseekV2MLP)
#             model.layers.3.mlp.experts.9.gate_proj (Linear)
#             model.layers.3.mlp.experts.9.up_proj (Linear)
#             model.layers.3.mlp.experts.9.down_proj (Linear)
#             model.layers.3.mlp.experts.9.act_fn (SiLU)
#           model.layers.3.mlp.experts.10 (DeepseekV2MLP)
#             model.layers.3.mlp.experts.10.gate_proj (Linear)
#             model.layers.3.mlp.experts.10.up_proj (Linear)
#             model.layers.3.mlp.experts.10.down_proj (Linear)
#             model.layers.3.mlp.experts.10.act_fn (SiLU)
#           model.layers.3.mlp.experts.11 (DeepseekV2MLP)
#             model.layers.3.mlp.experts.11.gate_proj (Linear)
#             model.layers.3.mlp.experts.11.up_proj (Linear)
#             model.layers.3.mlp.experts.11.down_proj (Linear)
#             model.layers.3.mlp.experts.11.act_fn (SiLU)
#           model.layers.3.mlp.experts.12 (DeepseekV2MLP)
#             model.layers.3.mlp.experts.12.gate_proj (Linear)
#             model.layers.3.mlp.experts.12.up_proj (Linear)
#             model.layers.3.mlp.experts.12.down_proj (Linear)
#             model.layers.3.mlp.experts.12.act_fn (SiLU)
#           model.layers.3.mlp.experts.13 (DeepseekV2MLP)
#             model.layers.3.mlp.experts.13.gate_proj (Linear)
#             model.layers.3.mlp.experts.13.up_proj (Linear)
#             model.layers.3.mlp.experts.13.down_proj (Linear)
#             model.layers.3.mlp.experts.13.act_fn (SiLU)
#           model.layers.3.mlp.experts.14 (DeepseekV2MLP)
#             model.layers.3.mlp.experts.14.gate_proj (Linear)
#             model.layers.3.mlp.experts.14.up_proj (Linear)
#             model.layers.3.mlp.experts.14.down_proj (Linear)
#             model.layers.3.mlp.experts.14.act_fn (SiLU)
#           model.layers.3.mlp.experts.15 (DeepseekV2MLP)
#             model.layers.3.mlp.experts.15.gate_proj (Linear)
#             model.layers.3.mlp.experts.15.up_proj (Linear)
#             model.layers.3.mlp.experts.15.down_proj (Linear)
#             model.layers.3.mlp.experts.15.act_fn (SiLU)
#           model.layers.3.mlp.experts.16 (DeepseekV2MLP)
#             model.layers.3.mlp.experts.16.gate_proj (Linear)
#             model.layers.3.mlp.experts.16.up_proj (Linear)
#             model.layers.3.mlp.experts.16.down_proj (Linear)
#             model.layers.3.mlp.experts.16.act_fn (SiLU)
#           model.layers.3.mlp.experts.17 (DeepseekV2MLP)
#             model.layers.3.mlp.experts.17.gate_proj (Linear)
#             model.layers.3.mlp.experts.17.up_proj (Linear)
#             model.layers.3.mlp.experts.17.down_proj (Linear)
#             model.layers.3.mlp.experts.17.act_fn (SiLU)
#           model.layers.3.mlp.experts.18 (DeepseekV2MLP)
#             model.layers.3.mlp.experts.18.gate_proj (Linear)
#             model.layers.3.mlp.experts.18.up_proj (Linear)
#             model.layers.3.mlp.experts.18.down_proj (Linear)
#             model.layers.3.mlp.experts.18.act_fn (SiLU)
#           model.layers.3.mlp.experts.19 (DeepseekV2MLP)
#             model.layers.3.mlp.experts.19.gate_proj (Linear)
#             model.layers.3.mlp.experts.19.up_proj (Linear)
#             model.layers.3.mlp.experts.19.down_proj (Linear)
#             model.layers.3.mlp.experts.19.act_fn (SiLU)
#           model.layers.3.mlp.experts.20 (DeepseekV2MLP)
#             model.layers.3.mlp.experts.20.gate_proj (Linear)
#             model.layers.3.mlp.experts.20.up_proj (Linear)
#             model.layers.3.mlp.experts.20.down_proj (Linear)
#             model.layers.3.mlp.experts.20.act_fn (SiLU)
#           model.layers.3.mlp.experts.21 (DeepseekV2MLP)
#             model.layers.3.mlp.experts.21.gate_proj (Linear)
#             model.layers.3.mlp.experts.21.up_proj (Linear)
#             model.layers.3.mlp.experts.21.down_proj (Linear)
#             model.layers.3.mlp.experts.21.act_fn (SiLU)
#           model.layers.3.mlp.experts.22 (DeepseekV2MLP)
#             model.layers.3.mlp.experts.22.gate_proj (Linear)
#             model.layers.3.mlp.experts.22.up_proj (Linear)
#             model.layers.3.mlp.experts.22.down_proj (Linear)
#             model.layers.3.mlp.experts.22.act_fn (SiLU)
#           model.layers.3.mlp.experts.23 (DeepseekV2MLP)
#             model.layers.3.mlp.experts.23.gate_proj (Linear)
#             model.layers.3.mlp.experts.23.up_proj (Linear)
#             model.layers.3.mlp.experts.23.down_proj (Linear)
#             model.layers.3.mlp.experts.23.act_fn (SiLU)
#           model.layers.3.mlp.experts.24 (DeepseekV2MLP)
#             model.layers.3.mlp.experts.24.gate_proj (Linear)
# ...
#             model.vision_model.transformer.layers.0.mlp.fc2 (Linear)
#           model.vision_model.transformer.layers.0.layer_norm1 (LayerNorm)
#           model.vision_model.transformer.layers.0.layer_norm2 (LayerNorm)
#         model.vision_model.transformer.layers.1 (NoTPTransformerBlock)
#           model.vision_model.transformer.layers.1.self_attn (NoTPAttention)
#             model.vision_model.transformer.layers.1.self_attn.qkv_proj (Linear)
#             model.vision_model.transformer.layers.1.self_attn.out_proj (Linear)
#           model.vision_model.transformer.layers.1.mlp (NoTPFeedForward)
#             model.vision_model.transformer.layers.1.mlp.fc1 (Linear)
#             model.vision_model.transformer.layers.1.mlp.fc2 (Linear)
#           model.vision_model.transformer.layers.1.layer_norm1 (LayerNorm)
#           model.vision_model.transformer.layers.1.layer_norm2 (LayerNorm)
#         model.vision_model.transformer.layers.2 (NoTPTransformerBlock)
#           model.vision_model.transformer.layers.2.self_attn (NoTPAttention)
#             model.vision_model.transformer.layers.2.self_attn.qkv_proj (Linear)
#             model.vision_model.transformer.layers.2.self_attn.out_proj (Linear)
#           model.vision_model.transformer.layers.2.mlp (NoTPFeedForward)
#             model.vision_model.transformer.layers.2.mlp.fc1 (Linear)
#             model.vision_model.transformer.layers.2.mlp.fc2 (Linear)
#           model.vision_model.transformer.layers.2.layer_norm1 (LayerNorm)
#           model.vision_model.transformer.layers.2.layer_norm2 (LayerNorm)
#         model.vision_model.transformer.layers.3 (NoTPTransformerBlock)
#           model.vision_model.transformer.layers.3.self_attn (NoTPAttention)
#             model.vision_model.transformer.layers.3.self_attn.qkv_proj (Linear)
#             model.vision_model.transformer.layers.3.self_attn.out_proj (Linear)
#           model.vision_model.transformer.layers.3.mlp (NoTPFeedForward)
#             model.vision_model.transformer.layers.3.mlp.fc1 (Linear)
#             model.vision_model.transformer.layers.3.mlp.fc2 (Linear)
#           model.vision_model.transformer.layers.3.layer_norm1 (LayerNorm)
#           model.vision_model.transformer.layers.3.layer_norm2 (LayerNorm)
#         model.vision_model.transformer.layers.4 (NoTPTransformerBlock)
#           model.vision_model.transformer.layers.4.self_attn (NoTPAttention)
#             model.vision_model.transformer.layers.4.self_attn.qkv_proj (Linear)
#             model.vision_model.transformer.layers.4.self_attn.out_proj (Linear)
#           model.vision_model.transformer.layers.4.mlp (NoTPFeedForward)
#             model.vision_model.transformer.layers.4.mlp.fc1 (Linear)
#             model.vision_model.transformer.layers.4.mlp.fc2 (Linear)
#           model.vision_model.transformer.layers.4.layer_norm1 (LayerNorm)
#           model.vision_model.transformer.layers.4.layer_norm2 (LayerNorm)
#         model.vision_model.transformer.layers.5 (NoTPTransformerBlock)
#           model.vision_model.transformer.layers.5.self_attn (NoTPAttention)
#             model.vision_model.transformer.layers.5.self_attn.qkv_proj (Linear)
#             model.vision_model.transformer.layers.5.self_attn.out_proj (Linear)
#           model.vision_model.transformer.layers.5.mlp (NoTPFeedForward)
#             model.vision_model.transformer.layers.5.mlp.fc1 (Linear)
#             model.vision_model.transformer.layers.5.mlp.fc2 (Linear)
#           model.vision_model.transformer.layers.5.layer_norm1 (LayerNorm)
#           model.vision_model.transformer.layers.5.layer_norm2 (LayerNorm)
#         model.vision_model.transformer.layers.6 (NoTPTransformerBlock)
#           model.vision_model.transformer.layers.6.self_attn (NoTPAttention)
#             model.vision_model.transformer.layers.6.self_attn.qkv_proj (Linear)
#             model.vision_model.transformer.layers.6.self_attn.out_proj (Linear)
#           model.vision_model.transformer.layers.6.mlp (NoTPFeedForward)
#             model.vision_model.transformer.layers.6.mlp.fc1 (Linear)
#             model.vision_model.transformer.layers.6.mlp.fc2 (Linear)
#           model.vision_model.transformer.layers.6.layer_norm1 (LayerNorm)
#           model.vision_model.transformer.layers.6.layer_norm2 (LayerNorm)
#         model.vision_model.transformer.layers.7 (NoTPTransformerBlock)
#           model.vision_model.transformer.layers.7.self_attn (NoTPAttention)
#             model.vision_model.transformer.layers.7.self_attn.qkv_proj (Linear)
#             model.vision_model.transformer.layers.7.self_attn.out_proj (Linear)
#           model.vision_model.transformer.layers.7.mlp (NoTPFeedForward)
#             model.vision_model.transformer.layers.7.mlp.fc1 (Linear)
#             model.vision_model.transformer.layers.7.mlp.fc2 (Linear)
#           model.vision_model.transformer.layers.7.layer_norm1 (LayerNorm)
#           model.vision_model.transformer.layers.7.layer_norm2 (LayerNorm)
#         model.vision_model.transformer.layers.8 (NoTPTransformerBlock)
#           model.vision_model.transformer.layers.8.self_attn (NoTPAttention)
#             model.vision_model.transformer.layers.8.self_attn.qkv_proj (Linear)
#             model.vision_model.transformer.layers.8.self_attn.out_proj (Linear)
#           model.vision_model.transformer.layers.8.mlp (NoTPFeedForward)
#             model.vision_model.transformer.layers.8.mlp.fc1 (Linear)
#             model.vision_model.transformer.layers.8.mlp.fc2 (Linear)
#           model.vision_model.transformer.layers.8.layer_norm1 (LayerNorm)
#           model.vision_model.transformer.layers.8.layer_norm2 (LayerNorm)
#         model.vision_model.transformer.layers.9 (NoTPTransformerBlock)
#           model.vision_model.transformer.layers.9.self_attn (NoTPAttention)
#             model.vision_model.transformer.layers.9.self_attn.qkv_proj (Linear)
#             model.vision_model.transformer.layers.9.self_attn.out_proj (Linear)
#           model.vision_model.transformer.layers.9.mlp (NoTPFeedForward)
#             model.vision_model.transformer.layers.9.mlp.fc1 (Linear)
#             model.vision_model.transformer.layers.9.mlp.fc2 (Linear)
#           model.vision_model.transformer.layers.9.layer_norm1 (LayerNorm)
#           model.vision_model.transformer.layers.9.layer_norm2 (LayerNorm)
#         model.vision_model.transformer.layers.10 (NoTPTransformerBlock)
#           model.vision_model.transformer.layers.10.self_attn (NoTPAttention)
#             model.vision_model.transformer.layers.10.self_attn.qkv_proj (Linear)
#             model.vision_model.transformer.layers.10.self_attn.out_proj (Linear)
#           model.vision_model.transformer.layers.10.mlp (NoTPFeedForward)
#             model.vision_model.transformer.layers.10.mlp.fc1 (Linear)
#             model.vision_model.transformer.layers.10.mlp.fc2 (Linear)
#           model.vision_model.transformer.layers.10.layer_norm1 (LayerNorm)
#           model.vision_model.transformer.layers.10.layer_norm2 (LayerNorm)
#         model.vision_model.transformer.layers.11 (NoTPTransformerBlock)
#           model.vision_model.transformer.layers.11.self_attn (NoTPAttention)
#             model.vision_model.transformer.layers.11.self_attn.qkv_proj (Linear)
#             model.vision_model.transformer.layers.11.self_attn.out_proj (Linear)
#           model.vision_model.transformer.layers.11.mlp (NoTPFeedForward)
#             model.vision_model.transformer.layers.11.mlp.fc1 (Linear)
#             model.vision_model.transformer.layers.11.mlp.fc2 (Linear)
#           model.vision_model.transformer.layers.11.layer_norm1 (LayerNorm)
#           model.vision_model.transformer.layers.11.layer_norm2 (LayerNorm)
#         model.vision_model.transformer.layers.12 (NoTPTransformerBlock)
#           model.vision_model.transformer.layers.12.self_attn (NoTPAttention)
#             model.vision_model.transformer.layers.12.self_attn.qkv_proj (Linear)
#             model.vision_model.transformer.layers.12.self_attn.out_proj (Linear)
#           model.vision_model.transformer.layers.12.mlp (NoTPFeedForward)
#             model.vision_model.transformer.layers.12.mlp.fc1 (Linear)
#             model.vision_model.transformer.layers.12.mlp.fc2 (Linear)
#           model.vision_model.transformer.layers.12.layer_norm1 (LayerNorm)
#           model.vision_model.transformer.layers.12.layer_norm2 (LayerNorm)
#         model.vision_model.transformer.layers.13 (NoTPTransformerBlock)
#           model.vision_model.transformer.layers.13.self_attn (NoTPAttention)
#             model.vision_model.transformer.layers.13.self_attn.qkv_proj (Linear)
#             model.vision_model.transformer.layers.13.self_attn.out_proj (Linear)
#           model.vision_model.transformer.layers.13.mlp (NoTPFeedForward)
#             model.vision_model.transformer.layers.13.mlp.fc1 (Linear)
#             model.vision_model.transformer.layers.13.mlp.fc2 (Linear)
#           model.vision_model.transformer.layers.13.layer_norm1 (LayerNorm)
#           model.vision_model.transformer.layers.13.layer_norm2 (LayerNorm)
#         model.vision_model.transformer.layers.14 (NoTPTransformerBlock)
#           model.vision_model.transformer.layers.14.self_attn (NoTPAttention)
#             model.vision_model.transformer.layers.14.self_attn.qkv_proj (Linear)
#             model.vision_model.transformer.layers.14.self_attn.out_proj (Linear)
#           model.vision_model.transformer.layers.14.mlp (NoTPFeedForward)
#             model.vision_model.transformer.layers.14.mlp.fc1 (Linear)
#             model.vision_model.transformer.layers.14.mlp.fc2 (Linear)
#           model.vision_model.transformer.layers.14.layer_norm1 (LayerNorm)
#           model.vision_model.transformer.layers.14.layer_norm2 (LayerNorm)
#         model.vision_model.transformer.layers.15 (NoTPTransformerBlock)
#           model.vision_model.transformer.layers.15.self_attn (NoTPAttention)
#             model.vision_model.transformer.layers.15.self_attn.qkv_proj (Linear)
#             model.vision_model.transformer.layers.15.self_attn.out_proj (Linear)
#           model.vision_model.transformer.layers.15.mlp (NoTPFeedForward)
#             model.vision_model.transformer.layers.15.mlp.fc1 (Linear)
#             model.vision_model.transformer.layers.15.mlp.fc2 (Linear)
#           model.vision_model.transformer.layers.15.layer_norm1 (LayerNorm)
#           model.vision_model.transformer.layers.15.layer_norm2 (LayerNorm)
#         model.vision_model.transformer.layers.16 (NoTPTransformerBlock)
#           model.vision_model.transformer.layers.16.self_attn (NoTPAttention)
#             model.vision_model.transformer.layers.16.self_attn.qkv_proj (Linear)
#             model.vision_model.transformer.layers.16.self_attn.out_proj (Linear)
#           model.vision_model.transformer.layers.16.mlp (NoTPFeedForward)
#             model.vision_model.transformer.layers.16.mlp.fc1 (Linear)
#             model.vision_model.transformer.layers.16.mlp.fc2 (Linear)
#           model.vision_model.transformer.layers.16.layer_norm1 (LayerNorm)
#           model.vision_model.transformer.layers.16.layer_norm2 (LayerNorm)
#         model.vision_model.transformer.layers.17 (NoTPTransformerBlock)
#           model.vision_model.transformer.layers.17.self_attn (NoTPAttention)
#             model.vision_model.transformer.layers.17.self_attn.qkv_proj (Linear)
#             model.vision_model.transformer.layers.17.self_attn.out_proj (Linear)
#           model.vision_model.transformer.layers.17.mlp (NoTPFeedForward)
#             model.vision_model.transformer.layers.17.mlp.fc1 (Linear)
#             model.vision_model.transformer.layers.17.mlp.fc2 (Linear)
#           model.vision_model.transformer.layers.17.layer_norm1 (LayerNorm)
#           model.vision_model.transformer.layers.17.layer_norm2 (LayerNorm)
#         model.vision_model.transformer.layers.18 (NoTPTransformerBlock)
#           model.vision_model.transformer.layers.18.self_attn (NoTPAttention)
#             model.vision_model.transformer.layers.18.self_attn.qkv_proj (Linear)
#             model.vision_model.transformer.layers.18.self_attn.out_proj (Linear)
#           model.vision_model.transformer.layers.18.mlp (NoTPFeedForward)
#             model.vision_model.transformer.layers.18.mlp.fc1 (Linear)
#             model.vision_model.transformer.layers.18.mlp.fc2 (Linear)
#           model.vision_model.transformer.layers.18.layer_norm1 (LayerNorm)
#           model.vision_model.transformer.layers.18.layer_norm2 (LayerNorm)
#         model.vision_model.transformer.layers.19 (NoTPTransformerBlock)
#           model.vision_model.transformer.layers.19.self_attn (NoTPAttention)
#             model.vision_model.transformer.layers.19.self_attn.qkv_proj (Linear)
#             model.vision_model.transformer.layers.19.self_attn.out_proj (Linear)
#           model.vision_model.transformer.layers.19.mlp (NoTPFeedForward)
#             model.vision_model.transformer.layers.19.mlp.fc1 (Linear)
#             model.vision_model.transformer.layers.19.mlp.fc2 (Linear)
#           model.vision_model.transformer.layers.19.layer_norm1 (LayerNorm)
#           model.vision_model.transformer.layers.19.layer_norm2 (LayerNorm)
#         model.vision_model.transformer.layers.20 (NoTPTransformerBlock)
#           model.vision_model.transformer.layers.20.self_attn (NoTPAttention)
#             model.vision_model.transformer.layers.20.self_attn.qkv_proj (Linear)
#             model.vision_model.transformer.layers.20.self_attn.out_proj (Linear)
#           model.vision_model.transformer.layers.20.mlp (NoTPFeedForward)
#             model.vision_model.transformer.layers.20.mlp.fc1 (Linear)
#             model.vision_model.transformer.layers.20.mlp.fc2 (Linear)
#           model.vision_model.transformer.layers.20.layer_norm1 (LayerNorm)
#           model.vision_model.transformer.layers.20.layer_norm2 (LayerNorm)
#         model.vision_model.transformer.layers.21 (NoTPTransformerBlock)
#           model.vision_model.transformer.layers.21.self_attn (NoTPAttention)
#             model.vision_model.transformer.layers.21.self_attn.qkv_proj (Linear)
#             model.vision_model.transformer.layers.21.self_attn.out_proj (Linear)
#           model.vision_model.transformer.layers.21.mlp (NoTPFeedForward)
#             model.vision_model.transformer.layers.21.mlp.fc1 (Linear)
#             model.vision_model.transformer.layers.21.mlp.fc2 (Linear)
#           model.vision_model.transformer.layers.21.layer_norm1 (LayerNorm)
#           model.vision_model.transformer.layers.21.layer_norm2 (LayerNorm)
#         model.vision_model.transformer.layers.22 (NoTPTransformerBlock)
#           model.vision_model.transformer.layers.22.self_attn (NoTPAttention)
#             model.vision_model.transformer.layers.22.self_attn.qkv_proj (Linear)
#             model.vision_model.transformer.layers.22.self_attn.out_proj (Linear)
#           model.vision_model.transformer.layers.22.mlp (NoTPFeedForward)
#             model.vision_model.transformer.layers.22.mlp.fc1 (Linear)
#             model.vision_model.transformer.layers.22.mlp.fc2 (Linear)
#           model.vision_model.transformer.layers.22.layer_norm1 (LayerNorm)
#           model.vision_model.transformer.layers.22.layer_norm2 (LayerNorm)
#         model.vision_model.transformer.layers.23 (NoTPTransformerBlock)
#           model.vision_model.transformer.layers.23.self_attn (NoTPAttention)
#             model.vision_model.transformer.layers.23.self_attn.qkv_proj (Linear)
#             model.vision_model.transformer.layers.23.self_attn.out_proj (Linear)
#           model.vision_model.transformer.layers.23.mlp (NoTPFeedForward)
#             model.vision_model.transformer.layers.23.mlp.fc1 (Linear)
#             model.vision_model.transformer.layers.23.mlp.fc2 (Linear)
#           model.vision_model.transformer.layers.23.layer_norm1 (LayerNorm)
#           model.vision_model.transformer.layers.23.layer_norm2 (LayerNorm)
#     model.vision_model.pre_layrnorm (LayerNorm)
#   model.projector (MlpProjector)
#     model.projector.layers (Linear)
# lm_head (Linear)
# ============================================================
#
# >>> Checking for Vision Encoder attributes:
#   - Could not find standard 'deep_encoder' or 'vision_model' attributes at top level.

# %%
# import torch
# from transformers import AutoModel
# import inspect

# def inspect_deepseek_components():
#     model_path = "deepseek-ai/DeepSeek-OCR"

#     print(f">>> Loading {model_path} (this may take a moment)...")
#     try:
#         # trust_remote_code=True is required for DeepSeek-OCR
#         model = AutoModel.from_pretrained(
#             model_path,
#             trust_remote_code=True,
#             torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32
#         )
#     except Exception as e:
#         print(f"Error loading model: {e}")
#         return

#     inner_model = model.model

#     print(f">>> Inspecting {inner_model.__class__.__name__}...")

#     # 2. We are looking for how 'sam_model' and 'vision_model' are connected.
#     # It is likely in 'forward' or a method called 'encode_images' bound to this class.
#     if hasattr(inner_model, "forward"):
#         source = inspect.getsource(inner_model.forward)
#         print(source)
#     else:
#       print("Could not find forward method on inner_model.")

# if __name__ == "__main__":
#     inspect_deepseek_components()
# Out:
# >>> Loading deepseek-ai/DeepSeek-OCR (this may take a moment)...
# You are using a model of type deepseek_vl_v2 to instantiate a model of type DeepseekOCR. This is not supported for all configurations of models and can yield errors.
# Some weights of DeepseekOCRForCausalLM were not initialized from the model checkpoint at deepseek-ai/DeepSeek-OCR and are newly initialized: ['model.vision_model.embeddings.position_ids']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# >>> Inspecting DeepseekOCRModel...
#     def forward(
#         self,
#         input_ids: torch.LongTensor = None,
#         attention_mask: Optional[torch.Tensor] = None,
#         position_ids: Optional[torch.LongTensor] = None,
#         past_key_values: Optional[List[torch.FloatTensor]] = None,
#         inputs_embeds: Optional[torch.FloatTensor] = None,
#         use_cache: Optional[bool] = None,
#         output_attentions: Optional[bool] = None,
#         output_hidden_states: Optional[bool] = None,
#         images: Optional[torch.FloatTensor] = None,
#         images_seq_mask: Optional[torch.FloatTensor] = None,
#         images_spatial_crop: Optional[torch.FloatTensor] = None,
#         return_dict: Optional[bool] = None,
#     ) -> Union[Tuple, BaseModelOutputWithPast]:
#
#
#
#
#         if inputs_embeds is None:
#             # inputs_embeds = self.embed_tokens(input_ids)
#             inputs_embeds = self.get_input_embeddings()(input_ids)
#
#
#
#         sam_model = getattr(self, 'sam_model', None)
#         # sam_model = self.sam_model
#         vision_model = getattr(self, 'vision_model', None)
#
#
#
#         if sam_model is not None and (input_ids.shape[1] != 1 or self.training) and torch.sum(images[0][1]).item() != 0:
#
#             idx = 0
#
#             # sam_model = torch.jit.script(sam_model)
#
#             # start_time = time.time()
#             for image, crop_shape in zip(images, images_spatial_crop):
#                 images_in_this_batch = []
#
#                 patches = image[0]
#                 image_ori = image[1]
#
#                 with torch.no_grad():
#                 # with torch.inference_mode():
#
#                     if torch.sum(patches).item() != 0:
#                         # P, C, H, W = patches.shape
#                         crop_flag = 1
#                         local_features_1 = sam_model(patches)
#
#                         local_features_2 = vision_model(patches, local_features_1)
#                         # vit_time = time.time()
#                         local_features = torch.cat((local_features_2[:, 1:], local_features_1.flatten(2).permute(0, 2, 1)), dim=-1)
#                         local_features = self.projector(local_features)
#
#
#                         global_features_1 = sam_model(image_ori)
#                         global_features_2 = vision_model(image_ori, global_features_1)
#                         global_features = torch.cat((global_features_2[:, 1:], global_features_1.flatten(2).permute(0, 2, 1)), dim=-1)
#                         global_features = self.projector(global_features)
#
#                         print('=====================')
#                         print('BASE: ', global_features.shape)
#                         print('PATCHES: ', local_features.shape)
#                         print('=====================')
#
#                         _, hw, n_dim = global_features.shape
#                         h = w = int(hw ** 0.5)
#
#                         _2, hw2, n_dim2 = local_features.shape
#                         h2 = w2 = int(hw2 ** 0.5)
#
#                         width_crop_num, height_crop_num = crop_shape[0], crop_shape[1]
#
#                         global_features = global_features.view(h, w, n_dim)
#
#                         global_features = torch.cat(
#                             [global_features, self.image_newline[None, None, :].expand(h, 1, n_dim)], dim=1
#                         )
#
#                         global_features = global_features.view(-1, n_dim)
#
#
#                         local_features = local_features.view(height_crop_num, width_crop_num, h2, w2, n_dim2).permute(0, 2, 1, 3, 4).reshape(height_crop_num*h2, width_crop_num*w2, n_dim2)
#                         local_features = torch.cat(
#                             [local_features, self.image_newline[None, None, :].expand(height_crop_num * h2, 1, n_dim2)], dim=1
#                         )
#                         local_features = local_features.view(-1, n_dim2)
#
#                         global_local_features = torch.cat([local_features, global_features, self.view_seperator[None, :]], dim=0)
#
#                         # end_time = time.time()
#
#                         # print('sam: ', sam_time - start_time)
#                         # print('vit: ', vit_time - sam_time)
#                         # print('all: ', end_time - start_time)
#
#                         # exit()
#
#                     else:
#                         global_features_1 = sam_model(image_ori)
#                         global_features_2 = vision_model(image_ori, global_features_1)
#                         global_features = torch.cat((global_features_2[:, 1:], global_features_1.flatten(2).permute(0, 2, 1)), dim=-1)
#                         global_features = self.projector(global_features)
#                         print('=====================')
#                         print('BASE: ', global_features.shape)
#                         print('NO PATCHES')
#                         print('=====================')
#                         _, hw, n_dim = global_features.shape
#                         h = w = int(hw ** 0.5)
#
#
#                         global_features = global_features.view(h, w, n_dim)
#
#                         global_features = torch.cat(
#                             [global_features, self.image_newline[None, None, :].expand(h, 1, n_dim)], dim=1
#                         )
#
#                         global_features = global_features.view(-1, n_dim)
#
#                         global_local_features = torch.cat([global_features, self.view_seperator[None, :]], dim=0)
#
#                     images_in_this_batch.append(global_local_features)
#
#
#                 # print(inputs_embeds.shape)
#
#                 if images_in_this_batch:
#                     images_in_this_batch = torch.cat(images_in_this_batch, dim=0)
#                     # exit()
#
#                     inputs_embeds[idx].masked_scatter_(images_seq_mask[idx].unsqueeze(-1).cuda(), images_in_this_batch)
#
#                 idx += 1
#
#
#         return super(DeepseekOCRModel, self).forward(
#             input_ids=None, attention_mask=attention_mask, past_key_values=past_key_values,
#             inputs_embeds=inputs_embeds, use_cache=use_cache, position_ids = position_ids,
#             output_attentions=output_attentions, output_hidden_states=output_hidden_states,
#             return_dict=return_dict
#         )
